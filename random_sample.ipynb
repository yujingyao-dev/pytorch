# %% [markdown]
# # Random sample
# Yu Jingyao, 1/13/2026

# %%
import torch

# %%
# 定义随机种子
torch.manual_seed(42)
a = torch.rand(2,2)
print(a)
# 不论执行多少次，结果都是固定的
# Out:
# tensor([[0.8823, 0.9150],
#         [0.3829, 0.9593]])
